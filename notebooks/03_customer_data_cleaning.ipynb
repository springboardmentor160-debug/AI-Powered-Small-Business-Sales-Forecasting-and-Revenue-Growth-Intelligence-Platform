# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.3)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.2)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python.exe m pip install --upgrade pip
# Out:
# python.exe: can't open file 'C:\\Users\\shrad\\Desktop\\Sales_Project\\notebooks\\m': [Errno 2] No such file or directory

# %%
import sys

# %%
# !{sys.executable} -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (26.1.1)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 2.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.2 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.1
#     Uninstalling pip-26.1.1:
#       Successfully uninstalled pip-26.1.1
# Successfully installed pip-26.2.1

# %%
# !{sys.executable} -m pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.3)
# Requirement already satisfied: openpyxl in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: et-xmlfile in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in C:\Users\shrad\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
sales = pd.read_excel("../data/raw/customer.xlsx")

# %%
sales.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
sales.shape
# Out:
# (541909, 8)

# %%
sales.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB

# %%
sales.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
sales.describe()
# Out:
#             Quantity                 InvoiceDate      UnitPrice     CustomerID
# count  541909.000000                      541909  541909.000000  406829.000000
# mean        9.552250  2011-07-04 13:34:57.156386       4.611114   15287.690570
# min    -80995.000000         2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%         1.000000         2011-03-28 11:34:00       1.250000   13953.000000
# 50%         3.000000         2011-07-19 17:17:00       2.080000   15152.000000
# 75%        10.000000         2011-10-19 11:27:00       4.130000   16791.000000
# max     80995.000000         2011-12-09 12:50:00   38970.000000   18287.000000
# std       218.081158                         NaN      96.759853    1713.600303

# %%
sales.duplicated().sum()
# Out:
# np.int64(5268)
